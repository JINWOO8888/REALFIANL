# %%
import pandas as pd

keyword = pd.read_csv('./dataset/IPR리스트_231218.csv')
print('키워드:', keyword.shape)
print(keyword.info())
# Out:
# 키워드: (959, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 959 entries, 0 to 958
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   KEYWORD  959 non-null    object
#  1   사유       959 non-null    object
#  2   코드       959 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 22.6+ KB
# None

# %%
keyword[['사유','코드']].value_counts()
# Out:
# 사유                                                     코드
# 금지약품 (Prohibited Drugs)                                2     661
# IPR 침해 (IPR Infringement)                              1     243
# 금지품목 (Prohibited Items)                                3      28
# IPR 침해 (IPR Infringement) + \n금지약품 (Prohibited Drugs)  6      14
# IPR 침해 (IPR Infringement) + 금지품목 (Prohibited Items)    5      10
# 성인용품(Explicit Adult)                                   4       3
# Name: count, dtype: int64

# %%
keyword[keyword['코드'] == 6 ]
# Out:
#               KEYWORD                                                 사유  코드
# 204         tadalafil  IPR 침해 (IPR Infringement) + \n금지약품 (Prohibited...   6
# 220           viaggra  IPR 침해 (IPR Infringement) + \n금지약품 (Prohibited...   6
# 272            Viagra  IPR 침해 (IPR Infringement) + \n금지약품 (Prohibited...   6
# 277            Cialis  IPR 침해 (IPR Infringement) + \n금지약품 (Prohibited...   6
# 281             Xanax  IPR 침해 (IPR Infringement) + \n금지약품 (Prohibited...   6
# 282           Norvasc  IPR 침해 (IPR Infringement) + \n금지약품 (Prohibited...   6
# 283          Celebrex  IPR 침해 (IPR Infringement) + \n금지약품 (Prohibited...   6
# 284        Genotropin  IPR 침해 (IPR Infringement) + \n금지약품 (Prohibited...   6
# 507           Kamagra  IPR 침해 (IPR Infringement) + \n금지약품 (Prohibited...   6
# 701          apetamin  IPR 침해 (IPR Infringement) + \n금지약품 (Prohibited...   6
# 721     La Pepa Negra  IPR 침해 (IPR Infringement) + \n금지약품 (Prohibited...   6
# ...

# %%
keyword[keyword['코드'] == 5 ]
# Out:
#               KEYWORD                                                 사유  코드
# 108          marlboro  IPR 침해 (IPR Infringement) + 금지품목 (Prohibited I...   5
# 109     philip morris  IPR 침해 (IPR Infringement) + 금지품목 (Prohibited I...   5
# 111            benson  IPR 침해 (IPR Infringement) + 금지품목 (Prohibited I...   5
# 225           Dunhill  IPR 침해 (IPR Infringement) + 금지품목 (Prohibited I...   5
# 226    Kent Cigarette  IPR 침해 (IPR Infringement) + 금지품목 (Prohibited I...   5
# 227  Butler Cigarette  IPR 침해 (IPR Infringement) + 금지품목 (Prohibited I...   5
# 228        Stuyvesant  IPR 침해 (IPR Infringement) + 금지품목 (Prohibited I...   5
# 231             Rizla  IPR 침해 (IPR Infringement) + 금지품목 (Prohibited I...   5
# 269           Malboro  IPR 침해 (IPR Infringement) + 금지품목 (Prohibited I...   5
# 270    Lambert Butler  IPR 침해 (IPR Infringement) + 금지품목 (Prohibited I...   5

# %%
keyword['사유'] = keyword[keyword['코드'] == 6 ]['사유'].str.replace('\n','')

# %%
keyword[keyword['코드'] == 6 ]
# Out:
#               KEYWORD                                                 사유  코드
# 204         tadalafil  IPR 침해 (IPR Infringement) + 금지약품 (Prohibited D...   6
# 220           viaggra  IPR 침해 (IPR Infringement) + 금지약품 (Prohibited D...   6
# 272            Viagra  IPR 침해 (IPR Infringement) + 금지약품 (Prohibited D...   6
# 277            Cialis  IPR 침해 (IPR Infringement) + 금지약품 (Prohibited D...   6
# 281             Xanax  IPR 침해 (IPR Infringement) + 금지약품 (Prohibited D...   6
# 282           Norvasc  IPR 침해 (IPR Infringement) + 금지약품 (Prohibited D...   6
# 283          Celebrex  IPR 침해 (IPR Infringement) + 금지약품 (Prohibited D...   6
# 284        Genotropin  IPR 침해 (IPR Infringement) + 금지약품 (Prohibited D...   6
# 507           Kamagra  IPR 침해 (IPR Infringement) + 금지약품 (Prohibited D...   6
# 701          apetamin  IPR 침해 (IPR Infringement) + 금지약품 (Prohibited D...   6
# 721     La Pepa Negra  IPR 침해 (IPR Infringement) + 금지약품 (Prohibited D...   6
# ...

# %%
#! pip install --upgrade pip
# ! pip install numpy scipy
! pip install gensim
# Out:
# ...
# DEPRECATION: mecab-python 0.996-ko-0.9.2-msvc has a non-standard version number. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of mecab-python or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import pandas as pd

import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize

# 예제 데이터프레임 생성

# 텍스트 데이터를 단어 단위로 토큰화
tokenized_text = [word_tokenize(sentence.lower()) for sentence in product['CATALOG_DESC']]

# Word2Vec 모델 학습
model = Word2Vec(sentences=tokenized_text, vector_size=100, window=5, min_count=1, workers=4)
# 이 때, vector_size는 단어 벡터의 차원 수를 지정합니다.
# window는 주변 단어의 범위를 나타냅니다.
# min_count는 최소 등장 횟수를 의미합니다.

# 단어 벡터 확인
word_vector = model.wv['word2vec']  # 'word2vec'라는 단어의 벡터를 가져옵니다.
print("Vector representation of 'word2vec':", word_vector)

# 단어 유사도 확인
similar_words = model.wv.most_similar('word2vec', topn=5)  # 'word2vec'와 유사한 단어를 찾습니다.
print("Words similar to 'word2vec':", similar_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 8
#       5 nltk.download('punkt')
#       7 from nltk.corpus import stopwords
# ----> 8 from gensim.models import Word2Vec
#       9 from nltk.tokenize import word_tokenize
#      11 # 예제 데이터프레임 생성
#      12
#      13 # 텍스트 데이터를 단어 단위로 토큰화
#
# ModuleNotFoundError: No module named 'gensim'
