# %% [markdown]
# # 데이터 로드

# %%
import pandas as pd

Weird_members = pd.read_csv('./dataset/이상회원데이터v2.csv')
Normal_members = pd.read_csv('./dataset/정상회원데이터v2.csv')
Weird_products = pd.read_csv('./dataset/이상상품_V2.csv')
Normal_products = pd.read_csv('./dataset/정상상품_V2.csv')
BlackLists = pd.read_csv('./dataset/블랙리스트_v2.csv')
BlockKeywords = pd.read_csv('./dataset/금지어keyword.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13608\1163122467.py:4: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   Normal_members = pd.read_csv('./dataset/정상회원데이터v2.csv')

# %% [markdown]
# # 데이터 확인

# %%
print('이상회원:', Weird_members.shape)
print('정상회원:', Normal_members.shape)
print('이상상품:', Weird_products.shape)
print('정상상품:', Normal_products.shape)
print('블랙리스트:', BlackLists.shape)
# Out:
# 이상회원: (93421, 17)
# 정상회원: (373343, 17)
# 이상상품: (212593, 12)
# 정상상품: (538722, 12)
# 블랙리스트: (26808, 8)

# %%
print('이상회원')

print(Weird_members.info())
# Out:
# 이상회원
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93421 entries, 0 to 93420
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MEMBER_ID   93421 non-null  object
#  1   GUBUN       93421 non-null  object
#  2   COUNTRY_CD  93416 non-null  object
#  3   ADDR1       91172 non-null  object
#  4   COMP_DESC   3 non-null      object
#  5   COMP_TITLE  4 non-null      object
#  6   COMP_INFO   91054 non-null  object
#  7   KEYWORD     90733 non-null  object
#  8   EMAIL1      93421 non-null  object
#  9   LOGIN_DT    93421 non-null  int64
#  10  LOGIN_CNT   93421 non-null  int64
#  11  INPUT_DT    93421 non-null  int64
#  12  UPDATE_DT   93421 non-null  int64
#  13  REMOTEIP    93421 non-null  object
#  14  SHOW_CHK    93421 non-null  object
#  15  MTYPE       93421 non-null  object
#  16  ORDER_FLG   93421 non-null  int64
# dtypes: int64(5), object(12)
# memory usage: 12.1+ MB
# None

# %%
print('정상회원')
print(Normal_members.info())
# Out:
# 정상회원
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373343 entries, 0 to 373342
# Data columns (total 17 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   MEMBER_ID   373343 non-null  object
#  1   GUBUN       373341 non-null  object
#  2   COUNTRY_CD  373163 non-null  object
#  3   ADDR1       266847 non-null  object
#  4   COMP_DESC   12 non-null      object
#  5   COMP_TITLE  16 non-null      object
#  6   COMP_INFO   100863 non-null  object
#  7   KEYWORD     100778 non-null  object
#  8   EMAIL1      373343 non-null  object
#  9   LOGIN_DT    373343 non-null  int64
#  10  LOGIN_CNT   373343 non-null  int64
#  11  INPUT_DT    373343 non-null  int64
#  12  UPDATE_DT   373343 non-null  int64
#  13  REMOTEIP    373343 non-null  object
#  14  SHOW_CHK    373343 non-null  object
#  15  MTYPE       373343 non-null  object
#  16  ORDER_FLG   373343 non-null  int64
# dtypes: int64(5), object(12)
# memory usage: 48.4+ MB
# None

# %%
print('이상물품')
print(Weird_products.info())
# Out:
# 이상물품
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212593 entries, 0 to 212592
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   MEMBER_ID     212593 non-null  object
#  1   GCATALOG_ID   212593 non-null  object
#  2   CATALOG_ID    212593 non-null  object
#  3   CATALOG_NM    212593 non-null  object
#  4   CATEGORYM_ID  212593 non-null  int64
#  5   KEYWORD       204281 non-null  object
#  6   DISPLAY       212593 non-null  object
#  7   CATALOG_DESC  212191 non-null  object
#  8   INPUT_DT      212593 non-null  int64
#  9   UPDATE_DT     212593 non-null  int64
#  10  REMOTEIP      212593 non-null  object
#  11  SHOW_CHK      212593 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 19.5+ MB
# None

# %%
print('정상회원')
print(Normal_products.info())
# Out:
# 정상회원
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 538722 entries, 0 to 538721
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   MEMBER_ID     538722 non-null  object
#  1   GCATALOG_ID   538722 non-null  object
#  2   CATALOG_ID    538722 non-null  object
#  3   CATALOG_NM    538722 non-null  object
#  4   CATEGORYM_ID  538722 non-null  int64
#  5   KEYWORD       536763 non-null  object
#  6   DISPLAY       538722 non-null  object
#  7   CATALOG_DESC  534487 non-null  object
#  8   INPUT_DT      538722 non-null  int64
#  9   UPDATE_DT     538722 non-null  int64
#  10  REMOTEIP      538722 non-null  object
#  11  SHOW_CHK      538722 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 49.3+ MB
# None

# %% [markdown]
# # 상품 concat

# %%
Normal_products['judge'] = 1
Weird_products['judge'] = 0

print(Weird_products.shape)
print(Normal_products.shape)
# Out:
# (212593, 13)
# (538722, 13)

# %%
Concat_products = pd.concat([Normal_products,Weird_products],ignore_index=True)

print(Concat_products.shape)
print(Concat_products.info())
# Out:
# (751315, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 751315 entries, 0 to 751314
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   MEMBER_ID     751315 non-null  object
#  1   GCATALOG_ID   751315 non-null  object
#  2   CATALOG_ID    751315 non-null  object
#  3   CATALOG_NM    751315 non-null  object
#  4   CATEGORYM_ID  751315 non-null  int64
#  5   KEYWORD       741044 non-null  object
#  6   DISPLAY       751315 non-null  object
#  7   CATALOG_DESC  746678 non-null  object
#  8   INPUT_DT      751315 non-null  int64
#  9   UPDATE_DT     751315 non-null  int64
#  10  REMOTEIP      751315 non-null  object
#  11  SHOW_CHK      751315 non-null  object
#  12  judge         751315 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 74.5+ MB
# None

# %%
print(Concat_products.isna().sum())
# concat_item.dropna(subset=['KEYWORD'],inplace=True)
#print(Concat_products.shape)
# Out:
# MEMBER_ID           0
# GCATALOG_ID         0
# CATALOG_ID          0
# CATALOG_NM          0
# CATEGORYM_ID        0
# KEYWORD         10271
# DISPLAY             0
# CATALOG_DESC     4637
# INPUT_DT            0
# UPDATE_DT           0
# REMOTEIP            0
# SHOW_CHK            0
# judge               0
# dtype: int64

# %%
Concat_products[Concat_products['CATALOG_DESC'].isna()]
# Out:
#                    MEMBER_ID GCATALOG_ID  CATALOG_ID  \
# 435              electronicx  GC11732966  CA11736086
# 613             nnlvshang888  GC11735806  CA11735818
# 622             nnlvshang888  GC11735806  CA11735807
# 842               jenson0809  GC11735426  CA11735482
# 1240             electronicx  GC11732966  CA11734701
# ...                      ...         ...         ...
# 724070           millswane63  GC10937035  CA10937041
# 727570  easytrippleaventures  GC10797082  CA10885719
# 729011         georgesgood22  GC10829969  CA10862284
# 735270                roby4u  GC09229975  CA10794858
# 742327            0638174422  GC10719295  CA10719456
#
#                                                CATALOG_NM  CATEGORYM_ID  \
# 435     Original Appls Watch Ultra Titanium Case with ...        400408
# 613     Virgin Pulp Cupboard Paper Cup Fan Use High Bu...        301308
# 622     7oz/8oz Paper Cup Fan PE Coated Paper Raw Mate...        301308
# 842                                        Paper Cup Funs          3038
# 1240    Original ECOVACS Deebot X1 Omni All-in-One Vac...          2355
# ...                                                   ...           ...
# 724070        Allen & Heath SQ5 48 Channel Digital Mixer            920
# 727570                         Snow White Petroleum Jelly        111104
# 729011             Fresh Red Apple Fruit Fresh Fuji Apple         14001
# 735270                         Pepa Negra Package of 2000        213699
# 742327                                      Pumpkin Seeds         15014
#
#                                                   KEYWORD DISPLAY  \
# 435                 Watches,Smart Watch,Appls Watch Ultra       Y
# 613     Cupboard Paper,Paper Cup Fan,Cup Paper Roll,PE...       Y
# 622     Paper Cup Fan,Coated Paper Raw Materia,Tea Cof...       Y
# 842                                        Paper Cup Funs       Y
# 1240    Vacuum Cleaner,ECOVACS Deebot X1,Robot Vacuum ...       Y
# ...                                                   ...     ...
# 724070                                      Digital Mixer       Y
# 727570                         Snow White Petroleum Jelly       N
# 729011      fresh apple,fresh red apples,fuji apple,Apple       N
# 735270                               sex,male,longer,safe       Y
# 742327  Pumpkin Seeds,sesame seed,hulled sesame seed,c...       N
#
#        CATALOG_DESC        INPUT_DT       UPDATE_DT         REMOTEIP SHOW_CHK  \
# 435             NaN  20230227052542  20230227060530     185.168.9.32        A
# 613             NaN  20230226155651  20230226155651      45.8.22.117        A
# 622             NaN  20230226154635  20230226154818      45.8.22.117        A
# 842             NaN  20230225155604  20230225155604   183.167.252.27        A
# 1240            NaN  20230224082028  20230226064359     185.168.9.34        A
# ...             ...             ...             ...              ...      ...
# 724070          NaN  20190409234105    202106020927    193.176.85.59        S
# 727570          NaN  20190102200247  20190811231154  210.187.213.114        P
# 729011          NaN  20181128192116  20190525231233     78.185.1.116        P
# 735270          NaN  20180808062804  20180808062804     71.47.75.203        B
# 742327          NaN  20180503024936  20190503231237       105.0.7.16        P
#
#         judge
# 435         1
# 613         1
# 622         1
# 842         1
# 1240        1
# ...       ...
# 724070      0
# 727570      0
# 729011      0
# 735270      0
# 742327      0
#
# [4637 rows x 13 columns]

# %%
print(Concat_products.dtypes)

Concat_products['CATEGORYM_ID'] = Concat_products['CATEGORYM_ID'].astype(str)
Concat_products['INPUT_DT'] = Concat_products['INPUT_DT'].astype(str)
Concat_products['UPDATE_DT'] = Concat_products['UPDATE_DT'].astype(str)
print(Concat_products.dtypes)
# Out:
# MEMBER_ID       object
# GCATALOG_ID     object
# CATALOG_ID      object
# CATALOG_NM      object
# CATEGORYM_ID    object
# KEYWORD         object
# DISPLAY         object
# CATALOG_DESC    object
# INPUT_DT        object
# UPDATE_DT       object
# REMOTEIP        object
# SHOW_CHK        object
# judge            int64
# dtype: object
# MEMBER_ID       object
# GCATALOG_ID     object
# CATALOG_ID      object
# CATALOG_NM      object
# CATEGORYM_ID    object
# KEYWORD         object
# DISPLAY         object
# CATALOG_DESC    object
# INPUT_DT        object
# UPDATE_DT       object
# REMOTEIP        object
# SHOW_CHK        object
# judge            int64
# dtype: object

# %% [markdown]
# ## todatetime 변경
# - K-Means 와는 맞지 않음
#
# - Concat_products['INPUT_DT']= pd.to_datetime(Concat_products['INPUT_DT'], format='%Y%m%d%H%M%S')
# - Concat_products['UPDATE_DT']= pd.to_datetime(Concat_products['UPDATE_DT'], format='%Y%m%d%H%M%S')

# %% [markdown]
# # 상품 군집화
# - 컬럼 선택

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np

k_range = range(1,10)

x = Concat_products[['CATALOG_DESC','DISPLAY','REMOTEIP']]


#data_for_clustering_numeric = pd.get_dummies(x.sample(n=3000))

Scaler = StandardScaler()
Scaled_x = scaler.fit_transform(data_for_clustering_numeric)
